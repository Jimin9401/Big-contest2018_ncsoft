    rec = recall_score(y_true = labels, y_pred = y_pred, average=None)
    f1_score = 8/(sum(1/pre) + sum(1/rec))

    return 'f1', f1_score

# %%
#### load data set
X_train = pd.read_csv('temp_data/train_every_features_0905.csv').drop('new_id',axis=1)
X_test = pd.read_csv('temp_data/test_every_features_0905.csv').drop('new_id',axis=1)

# %%
#### train_trade 제거
candidate_features = pd.read_csv('temp_data/candidate_features.csv',header=None)[0]
drop_trade_list = pd.read_csv('temp_data/training_trade.csv').iloc[:,1:].columns.tolist()

cols = [x for x in candidate_features.tolist() if x not in drop_trade_list] 

X_train = X_train.loc[:,cols]
X_test = X_test.loc[:,cols]

# %%
#### load class
train_label = pd.read_csv('temp_data/train_label_lite.csv')
hasher = pd.read_csv('temp_data/test_id.csv')
label_map = {'retained':0,'2month':1,'month':2,'week':3}
y_train = pd.Series([label_map[l] for l in train_label.label])
inv_map = {label_map[k]:k for k in label_map.keys()}

# %%
X_train1 = pd.read_csv('temp_data/train_0906_added.csv').drop('new_id',axis=1)
X_test1 = pd.read_csv('temp_data/test_0906_added.csv').drop('new_id',axis=1)

# %%
X_test_temp = pd.read_csv('first_last_trade_all.csv')

# %%
X_train = pd.concat((X_train,X_train1),axis = 1)
X_test = pd.concat((X_test,X_test1,X_test_temp),axis = 1)

# %%
X_test = X_test.loc[:,X_train.columns.tolist()]

# %%
## drop noise
X_train_ot = X_train.iloc[noise,:]
y_train_ot = y_train.iloc[noise]

# %%
X_train_ot = X_train_ot.loc[:,(X_train_ot.std().fillna(0.0) != 0)]

# %%
X_train_ot = X_train_ot.reset_index()
y_train_ot = y_train_ot.reset_index(drop=True)

# %%
X_train = X_train_ot.iloc[:,1:]
y_train = y_train_ot

# %%
#######
rows = [x for x in range(len(X_train)) if x not in noise]

## drop noise
X_train_ok = X_train.iloc[rows,:]
y_train_ok = y_train.iloc[rows]

X_train_ok = X_train_ok.reset_index()
y_train_ok = y_train_ok.reset_index(drop=True)

# %%
X_train = X_train_ok.iloc[:,1:]
y_train = y_train_ok

# %% [markdown]
# ---

# %%
#### split
X_train_tr, X_val, y_train_tr, y_val = separating(X_train,y_train)
# Out:
# [87143 28519 68337 ..., 10073  3986 63774]
# [78530 31185 87926 ..., 83511 12888 48399]
# [50790 47662 53438 ...,   164 27360 86649]
# [86329 30314 32126 ..., 85367 65430 87119]

# %%
xgtrain_tr = xgb.DMatrix(X_train_tr.values, label= y_train_tr.values.reshape(-1,1))
xgval_tr = xgb.DMatrix(X_val.values, label= y_val.values.reshape(-1,1))
watchlist = [(xgval_tr, 'eval')]

# %%
import joblib
past_model = joblib.load('xgb_01.model')

# %%
past_model.get_booster
# Out:
# <bound method XGBModel.get_booster of XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.75, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=10, min_child_weight=4.006032864283637, missing=nan,
#        n_estimators=410, n_gpus=-1, n_jobs=1, nthread=None, num_class=4,
#        objective='multi:softprob', random_state=0, reg_alpha=0.072,
#        reg_lambda=0.006, scale_pos_weight=1, seed=7, silent=0,
#        subsample=0.95, tree_method='gpu_hist')>

# %%
past_model = xgb.train(param, xgtrain_tr, num_boost_round = param['n_estimators'],feval=F1, evals=watchlist)
past_model.save_model('test.model')
model = xgb.train(param, xgtrain, num_boost_round = param['n_estimators'],feval=F1,maximize=True, evals=watchlist,xgb_model='test.model')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b9e6d19cb165> in <module>()
# ----> 1 past_model = xgb.train(param, xgtrain, num_boost_round = param['n_estimators'],feval=F1,maximize=True, evals=watchlist)
#       2 past_model.save_model('test.model')
#       3 model = xgb.train(param, xgtrain, num_boost_round = param['n_estimators'],feval=F1,maximize=True, evals=watchlist,xgb_model='test.model')
#
# NameError: name 'param' is not defined

# %% [markdown]
# ---

# %%
#### xgb
grid_result = []
param = {}
#### XGB parameters
## General Parameters
param['n_gpus'] = -1
param['tree_method'] = 'gpu_hist'
param['silent'] = 0

## Booster Parameters
param['n_estimators'] = 1000 #요기...
param['learning_rate'] = 0.1
param['min_child_weight'] = 6.5
param['max_depth'] = 13
param['gamma'] = 0.1
param['reg_alpha'] =0.01
param['reg_lambda'] = 0.05
param['subsample'] = 0.9
param['colsample_bytree'] = 0.75
param['scale_pos_weight'] = 1

## Learning task parameters
param['num_class'] = 4
param['objective'] = 'multi:softmax'
param['seed'] = 7

## update?
#param['process_type'] = 'update'
#param['updater'] = 'refresh'
#param['refresh_leaf'] = True

# %%
 #### step 1 : tuning n_estimators with cross validation
print("===============================================")
print("Find the n_estimators")
xgtrain = xgb.DMatrix(X_train.values, label= y_train.values.reshape(-1,1))
cvresult = xgb.cv(param, xgtrain, num_boost_round = param['n_estimators'], nfold = 5, feval=F1, early_stopping_rounds = 100
                  ,stratified=True, shuffle=True, verbose_eval = True)
print("Optimal n_estimators : %d"%cvresult.shape[0])
# Out:
# ...
# Find the n_estimators
# [0]	train-f1:0.732397+0.00156754	train-merror:0.249333+0.00109591	test-f1:0.68173+0.00360104	test-merror:0.29752+0.00318113
# [1]	train-f1:0.749849+0.0019177	train-merror:0.231777+0.00179899	test-f1:0.694434+0.00325844	test-merror:0.28382+0.00253961
# [2]	train-f1:0.757726+0.0020102	train-merror:0.224355+0.00166892	test-f1:0.698278+0.00287531	test-merror:0.27975+0.00247022
# [3]	train-f1:0.7631+0.00256098	train-merror:0.219162+0.00189102	test-f1:0.7011+0.00271685	test-merror:0.27687+0.00254963
# [4]	train-f1:0.766507+0.00170868	train-merror:0.215853+0.00108932	test-f1:0.702629+0.00259156	test-merror:0.27524+0.00239883
# [5]	train-f1:0.769629+0.00175251	train-merror:0.212705+0.00125218	test-f1:0.703062+0.00283935	test-merror:0.27433+0.00268041
# [6]	train-f1:0.773302+0.00148737	train-merror:0.20936+0.00109304	test-f1:0.704424+0.00252835	test-merror:0.27337+0.00235087
# ...

# %%
#### 기존 min만 다넣고....
cvresult['test-f1-mean'].max()
# Out:
# 0.7193368

# %%
#### 새로... 13/6.5
cvresult['test-f1-mean'].max()
# Out:
# 0.72376799999999997

# %%
#### 새로... 15/7
cvresult['test-f1-mean'].max()
# Out:
# 0.723302

# %%
#### 0907,,,
cvresult['test-f1-mean'].max()
# Out:
# 0.7239549999999999

# %% [markdown]
# ---

# %%
#### xgb
grid_result = []
param = {}
#### XGB parameters
## General Parameters
param['n_gpus'] = -1
param['tree_method'] = 'gpu_hist'
param['silent'] = 0

## Booster Parameters
param['n_estimators'] = 2240 #요기...
param['learning_rate'] = 0.01
param['min_child_weight'] = 6.5
param['max_depth'] = 13
param['gamma'] = 0.1
param['reg_alpha'] =0.01
param['reg_lambda'] = 0.05
param['subsample'] = 0.9
param['colsample_bytree'] = 0.75
param['scale_pos_weight'] = 1

## Learning task parameters
param['num_class'] = 4
param['objective'] = 'multi:softmax'
param['seed'] = 7

## update?
#param['process_type'] = 'update'
#param['updater'] = 'refresh'
#param['refresh_leaf'] = True

# %%
past_model = xgb.train(param, xgtrain_tr, num_boost_round = param['n_estimators'],feval=F1, maximize=True,evals=watchlist,early_stopping_rounds=100)
# Out:
# [0]	eval-merror:0.2918	eval-f1:0.688755
# Multiple eval metrics have been passed: 'eval-f1' will be used for early stopping.
#
# Will train until eval-f1 hasn't improved in 100 rounds.
# [1]	eval-merror:0.284	eval-f1:0.69529
# [2]	eval-merror:0.279	eval-f1:0.697253
# [3]	eval-merror:0.275	eval-f1:0.700708
# [4]	eval-merror:0.2733	eval-f1:0.702233
# [5]	eval-merror:0.2741	eval-f1:0.701602
# [6]	eval-merror:0.2713	eval-f1:0.704299
# [7]	eval-merror:0.2708	eval-f1:0.705333
# [8]	eval-merror:0.2706	eval-f1:0.705012
# [9]	eval-merror:0.2698	eval-f1:0.705847
# [10]	eval-merror:0.2688	eval-f1:0.706588
# [11]	eval-merror:0.2684	eval-f1:0.70725
# [12]	eval-merror:0.2671	eval-f1:0.709512
# [13]	eval-merror:0.2676	eval-f1:0.709284
# [14]	eval-merror:0.2677	eval-f1:0.709014
# [15]	eval-merror:0.267	eval-f1:0.709618
# [16]	eval-merror:0.2663	eval-f1:0.710821
# [17]	eval-merror:0.265	eval-f1:0.712127
# [18]	eval-merror:0.2658	eval-f1:0.711293
# [19]	eval-merror:0.267	eval-f1:0.709405
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### test

# %%
#### xgb
grid_result = []
param = {}
#### XGB parameters
## General Parameters
param['n_gpus'] = -1
param['tree_method'] = 'gpu_hist'
param['silent'] = 0

## Booster Parameters
param['n_estimators'] = 285 #요기...
param['learning_rate'] = 0.1
param['min_child_weight'] = 7
param['max_depth'] = 15
param['gamma'] = 0.1
param['reg_alpha'] =0.01
param['reg_lambda'] = 0.05
param['subsample'] = 0.9
param['colsample_bytree'] = 0.75
param['scale_pos_weight'] = 1

## Learning task parameters
param['num_class'] = 4
param['objective'] = 'multi:softmax'
param['seed'] = 7

## update?
#param['process_type'] = 'update'
#param['updater'] = 'refresh'
#param['refresh_leaf'] = True

# %%
#### 전체 데이터 학습
model = xgb.XGBClassifier(**param)
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.75, gamma=0.1, learning_rate=0.01,
#        max_delta_step=0, max_depth=13, min_child_weight=6.5, missing=None,
#        n_estimators=2240, n_gpus=-1, n_jobs=1, nthread=None, num_class=4,
#        objective='multi:softprob', random_state=0, reg_alpha=0.01,
#        reg_lambda=0.05, scale_pos_weight=1, seed=7, silent=0,
#        subsample=0.9, tree_method='gpu_hist')

# %%
xgb_prob = pd.DataFrame(model.predict_proba(X_test),columns=['y_pred_prob0', 'y_pred_prob1', 'y_pred_prob2','y_pred_prob3'])

# %%
xgb_prob.to_csv('xgb_fin.csv',index = False)

# %%
my_pred = model.predict(X_test)

# %%
#### result
results = [inv_map[x] for x in my_pred]
result = pd.DataFrame({'acc_id':['te' + str(x) for x in X_test.index], 'label': results})
result['acc_id'] = [hasher.iloc[i,0] for i in range(len(result.acc_id))]

# %%
result.to_csv('last_3.csv',index = False)

# %% [markdown]
# ### Feature importance

# %%
### features 
gains = model.get_booster().get_score(importance_type='gain')
gain = pd.DataFrame([(k,gains[k]) for k in gains]).sort_values(by=1,ascending = False)
gain.columns = ['feature','inforamtion_gain']
gain.reset_index(drop=True,inplace=True)

covers = model.get_booster().get_score(importance_type='cover')
cover = pd.DataFrame([(k,covers[k]) for k in covers]).sort_values(by=1,ascending = False)
cover.columns = ['feature','cover']
cover.reset_index(drop=True,inplace=True)

freq = model.get_booster().get_score(importance_type='weight')
freq= pd.DataFrame([(k ,freq[k]) for k in freq.keys()]).sort_values(by=1,ascending = False)
freq.columns = ['feature','freq']
freq.reset_index(drop=True,inplace=True)

# %%
total = pd.merge(gain,cover)
total = pd.merge(total, freq)
total['rule'] = total.cover / total.freq
total.to_csv('feature_importance_with_new.csv',index = False)

# %% [markdown]
# ---

# %%
#### xgb
grid_result = []
param = {}
#### XGB parameters
## General Parameters
param['n_gpus'] = -1
param['tree_method'] = 'gpu_hist'
param['silent'] = 0

## Booster Parameters
param['n_estimators'] = 224 #요기...
param['learning_rate'] = 0.1
param['min_child_weight'] = 6.5
param['max_depth'] = 13
param['gamma'] = 0.1
param['reg_alpha'] =0.01
param['reg_lambda'] = 0.05
param['subsample'] = 0.9
param['colsample_bytree'] = 0.75
param['scale_pos_weight'] = 1

## Learning task parameters
param['num_class'] = 4
param['objective'] = 'multi:softmax'
param['seed'] = 7

## update?
#param['process_type'] = 'update'
#param['updater'] = 'refresh'
#param['refresh_leaf'] = True
model = xgb.XGBClassifier(**param)

# %%
7578 - 6061
# Out:
# 1517

# %%
92422 - 73935
# Out:
# 18487

# %%
19752+17570+17409+19204
# Out:
# 73935

# %%
#### cross validation(for NA)
kfold = StratifiedKFold(n_splits = 5 ,random_state = 7,shuffle=True).split(X_train, y_train)
scores = []
predict_set = []
for k, (train, test) in enumerate(kfold):
    model.fit(X_train.iloc[train,:], y_train[train],eval_metric = F1)  ####요부분 trimming
    score = model.score(X_train.iloc[test,:], y_train[test])
    scores.append(score)
    print('Fold: %s, Class dist.: %s, F1: %.3f' % (k+1,np.bincount(y_train[train]), score))
    ### predict
    y_pred = model.predict(X_train.iloc[test,:])
    predict_set += [(x,inv_map[y_pred[i]]) for i,x in enumerate(test)]
print('\nCV F1: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Fold: 1, Class dist.: [ 247 2429 2590  795], F1: 0.520
# Fold: 2, Class dist.: [ 247 2429 2590  795], F1: 0.515
# Fold: 3, Class dist.: [ 247 2430 2590  795], F1: 0.500
# Fold: 4, Class dist.: [ 247 2430 2591  795], F1: 0.500
# Fold: 5, Class dist.: [ 248 2430 2591  796], F1: 0.517
#
# CV F1: 0.511 +/- 0.009

# %%
X_train_ot
# Out:
#       index  trade_InDeg  trade_InDegCen  num_guild  \
# 0         0          0.0             0.0          0
# 1        15          0.0             0.0          0
# 2        18          0.0             0.0          0
# 3        20          0.0             0.0          1
# 4        31          0.0             0.0          0
# 5        33          0.0             0.0          0
# 6        41          0.0             0.0          0
# 7        43          0.0             0.0          0
# 8        50          0.0             0.0          0
# 9        51          0.0             0.0          0
# 10       65          0.0             0.0          0
# 11       69          0.0             0.0          0
# 12      101          0.0             0.0          0
# 13      104          0.0             0.0          0
# 14      122          0.0             0.0          0
# 15      152          0.0             0.0          0
# 16      176          0.0             0.0          0
# ...

# %%
error_set = pd.merge(X_train_ot.iloc[:,:1],pd.DataFrame(predict_set),left_on = X_train_ot.index,right_on = 0).drop(0,axis=1)

# %%
#### cross validation(for NA)
kfold = StratifiedKFold(n_splits = 5 ,random_state = 7,shuffle=True).split(X_train, y_train)
scores = []
predict_set = []
for k, (train, test) in enumerate(kfold):
    model.fit(X_train.iloc[train,:], y_train[train],eval_metric = F1)  ####요부분 trimming
    score = model.score(X_train.iloc[test,:], y_train[test])
    scores.append(score)
    print('Fold: %s, Class dist.: %s, F1: %.3f' % (k+1,np.bincount(y_train[train]), score))
    ### predict
    y_pred = model.predict(X_train.iloc[test,:])
    predict_set += [(x,inv_map[y_pred[i]]) for i,x in enumerate(test)]
print('\nCV F1: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Fold: 1, Class dist.: [19752 17570 17409 19204], F1: 0.759
# Fold: 2, Class dist.: [19753 17570 17409 19205], F1: 0.758
# Fold: 3, Class dist.: [19753 17570 17410 19205], F1: 0.757
# Fold: 4, Class dist.: [19753 17571 17410 19205], F1: 0.762
# Fold: 5, Class dist.: [19753 17571 17410 19205], F1: 0.761
#
# CV F1: 0.760 +/- 0.002

# %%
result = pd.concat((error_set.iloc[:1517,:],fulls.iloc[:18487,:])).reset_index(drop=True)

# %%
result = pd.merge(train_label,result, left_on = train_label.index, right_on = 'index',how = 'right')

# %%
    pre = precision_score(y_true = result.label, y_pred = result[1], average=None)
    rec = recall_score(y_true = result.label, y_pred = result[1], average=None)
    f1_score = 8/(sum(1/pre) + sum(1/rec))

# %%
print(f1_score)
# Out:
# 0.722325778179

# %%
pd.merge(train_label)

# %%
result.sort_values(by='index')
# Out:
#       index         1
# 0         0    2month
# 1517      1      week
# 1518      2  retained
# 1519      3      week
# 1520      4  retained
# 1521      5    2month
# 1522      6     month
# 1523      7  retained
# 1524      8    2month
# 1525      9    2month
# 1526     10     month
# 1527     11  retained
# 1528     12  retained
# 1529     13    2month
# 1530     14    2month
# 1        15    2month
# 1531     16      week
# 1532     17     month
# 2        18    2month
# 1533     19  retained
# 3        20     month
# 1534     21     month
# 1535     22      week
# 1536     23  retained
# 1537     24      week
# 1538     25     month
# 1539     26    2month
# 1540     27      week
# 1541     28     month
# 1542     29    2month
# ...     ...       ...
# 1487  20102     month
# 1488  20103     month
# 1489  20106     month
# 1490  20123    2month
# 1491  20133     month
# 1492  20138     month
# 1493  20145      week
# 1494  20211     month
# 1495  20220    2month
# ...

# %%
error_set.iloc[:1517,:]
# Out:
#       index       1
# 0         0  2month
# 1        15  2month
# 2        18  2month
# 3        20   month
# 4        31    week
# 5        33   month
# 6        41   month
# 7        43   month
# 8        50   month
# 9        51   month
# 10       65  2month
# 11       69  2month
# 12      101  2month
# 13      104   month
# 14      122   month
# 15      152   month
# 16      176   month
# 17      188   month
# 18      207    week
# 19      211  2month
# 20      222   month
# 21      232  2month
# 22      236   month
# 23      241   month
# 24      242   month
# 25      286   month
# 26      322  2month
# 27      326  2month
# 28      327   month
# 29      368   month
# ...     ...     ...
# 1487  20102   month
# 1488  20103   month
# 1489  20106   month
# 1490  20123  2month
# 1491  20133   month
# 1492  20138   month
# 1493  20145    week
# 1494  20211   month
# 1495  20220  2month
# 1496  20229   month
# 1497  20239    week
# 1498  20240  2month
# 1499  20245   month
# ...

# %%
fulls = pd.merge(X_train_ok.iloc[:,:1],pd.DataFrame(predict_set),left_on = X_train_ok.index,right_on = 0).drop(0,axis=1)

# %% [markdown]
# ---

# %%
model.save_model('xgb_0.744')

# %%
#### 오분류 데이터 셋
error_dataset = pd.merge(train_label,pd.DataFrame(predict_set,columns=['ind','y_pred']),left_on=train_label.index,right_on='ind')
error_dataset.drop(labels='ind',axis=1,inplace=True)

# %%
error_dataset.to_csv('error_set_0.742.csv',index = False)

# %%
importance = model.feature_importances_

# %%
FI_result = [(c, importance[i]) for i, c in enumerate(X_train.columns)]

# %%
FI_result
# Out:
# [('play_time_by_cnt_dt', 0.025736388),
#  ('play_time_var_time_series', 0.014651859),
#  ('play_time_MA_5_time_series', 0.014782408),
#  ('play_time_median_stat', 0.016482582),
#  ('play_time_sum_stat', 0.01122115),
#  ('play_time_max_stat', 0.012717911),
#  ('play_time_mean_time_series', 0.0028569),
#  ('game_combat_time_max_stat', 0.011567257),
#  ('play_time_diff_w4_by_last_time_series', 0.014660967),
#  ('play_time_diff_w8_by_last_time_series', 0.013431377),
#  ('play_time_min_stat', 0.019709878),
#  ('play_time_diff_w2_by_last_time_series', 0.013300828),
#  ('pattern_retained', 0.003327484),
#  ('play_time_diff7_time_series', 0.015413902),
#  ('game_combat_time_MA_5_time_series', 0.0055893231),
#  ('game_combat_time_sum_stat', 0.0054193055),
#  ('game_combat_time_by_play_time', 0.017007815),
#  ('cnt_dt_mean_time_series', 0.0063908338),
#  ('game_combat_time_diff_w8_by_last_time_series', 0.0048090643),
#  ('game_combat_time_var_time_series', 0.0029358366),
# ...

# %%
pd.DataFrame(FI_result).sort_values(by=1,ascending= False).head(100)
# Out:
#                                                 0         1
# 0                             play_time_by_cnt_dt  0.025736
# 10                             play_time_min_stat  0.019710
# 16                  game_combat_time_by_play_time  0.017008
# 3                           play_time_median_stat  0.016483
# 13                    play_time_diff7_time_series  0.015414
# 2                      play_time_MA_5_time_series  0.014782
# 8           play_time_diff_w4_by_last_time_series  0.014661
# 1                       play_time_var_time_series  0.014652
# 31                     play_time_kurt_time_series  0.014245
# 43                    play_time_cycle_time_series  0.013920
# 9           play_time_diff_w8_by_last_time_series  0.013431
# 11          play_time_diff_w2_by_last_time_series  0.013301
# 5                              play_time_max_stat  0.012718
# 32                     play_time_skew_time_series  0.011640
# 7                       game_combat_time_max_stat  0.011567
# ...

# %%
importance.shape
# Out:
# (438,)

# %%
fig, ax = plt.subplots(figsize=(14,36))
xgb.plot_importance(model, max_num_features=200, height=0.8, ax=ax)
plt.show()

# %% [markdown]
# ### FINE TUNING

# %%
#### xgb
grid_result = []
param = {}
#### XGB parameters
## General Parameters
param['n_gpus'] = -1
param['tree_method'] = 'gpu_hist'
param['silent'] = 0

## Booster Parameters
param['n_estimators'] = 600 #요기...
param['learning_rate'] = 0.001
param['min_child_weight'] = 2
param['max_depth'] = 10
param['gamma'] = 0
param['reg_alpha'] = 0.1
param['reg_lambda'] = 0.03
param['subsample'] = 0.9
param['colsample_bytree'] = 0.75
param['scale_pos_weight'] = 1

## Learning task parameters
param['num_class'] = 4
param['objective'] = 'multi:softmax'
param['seed'] = 7

model = xgb.XGBClassifier(**param)

# %%
model.load_model('xgb_0.7344')

# %%
#### 기존 state of art 학습!!!
model.fit(X_train,y_train,eval_metric = F1)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.75, gamma=0, learning_rate=0.01,
#        max_delta_step=0, max_depth=10, min_child_weight=2, missing=None,
#        n_estimators=3000, n_gpus=-1, n_jobs=1, nthread=None, num_class=4,
#        objective='multi:softprob', random_state=0, reg_alpha=0.1,
#        reg_lambda=0.03, scale_pos_weight=1, seed=7, silent=0,
#        subsample=0.9, tree_method='gpu_hist')

# %%
soa_booster = model.get_booster

# %%
#### xgb
grid_result = []
param = {}
#### XGB parameters
## General Parameters
param['n_gpus'] = -1
param['tree_method'] = 'gpu_hist'
param['silent'] = 0

## Booster Parameters
param['n_estimators'] = 600 # 길게 잡고...
param['learning_rate'] = 0.001 # learning rate를 더 줄여서...
param['min_child_weight'] = 2
param['max_depth'] = 10
param['gamma'] = 0
param['reg_alpha'] = 0.1
param['reg_lambda'] = 0.03
param['subsample'] = 0.9
param['colsample_bytree'] = 0.75
param['scale_pos_weight'] = 1

## Learning task parameters
param['num_class'] = 4
param['objective'] = 'multi:softmax'
param['seed'] = 7

model = xgb.XGBClassifier(**param)

# %% [markdown]
# ### final model

# %%
#### cross validation(for NA)
kfold = StratifiedKFold(n_splits = 5 ,random_state = 7,shuffle=True).split(X_train, y_train)
scores = []
predict_set = []
for k, (train, test) in enumerate(kfold):
    model.fit(X_train.iloc[train,:], y_train[train],eval_metric = F1)  ####요부분 trimming
    score = model.score(X_train.iloc[test,:], y_train[test])
    scores.append(score)
    print('Fold: %s, Class dist.: %s, F1: %.3f' % (k+1,np.bincount(y_train[train]), score))
    ### predict
    y_pred = model.predict(X_train.iloc[test,:])
    predict_set += [(x,inv_map[y_pred[i]]) for i,x in enumerate(test)]
print('\nCV F1: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-624da078ae48> in <module>()
#       6     model.fit(X_train.iloc[train,:], y_train[train],eval_metric = F1
#       7               ,eval_set=[(X_train.iloc[test,:], y_train[test])]
# ----> 8               ,early_stopping_rounds=100, xgb_model = soa_booster)  ####요부분 trimming
#       9
#      10     score = model.score(X_train.iloc[test,:], y_train[test])
#
# /opt/conda/lib/python3.6/site-packages/xgboost-0.80-py3.6.egg/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set)
#     589                               early_stopping_rounds=early_stopping_rounds,
#     590                               evals_result=evals_result, obj=obj, feval=feval,
# --> 591                               verbose_eval=verbose, xgb_model=None)
# ...

# %%
import joblib
#save model
joblib.dump(xgb, filename) 

#load saved model
xgb = joblib.load(filename)

# %%
fig, ax = plt.subplots(figsize=(14,60))
xgb.plot_importance(model, max_num_features=340, height=0.8, ax=ax)
plt.show()

# %%
#### load data set
## train
X_train1 = pd.read_csv('temp_data/X_train_stat.csv')
X_train2 = pd.read_csv('temp_data/X_train_easy_time.csv').drop('new_id',axis=1)
X_train2.columns = [x +'_basic_time' for x in X_train2.columns]
X_train3 = pd.read_csv('temp_data/X_train_게임활동_time.csv').drop('new_id',axis=1)
X_train3.columns = [x +'_time_series' for x in X_train3.columns]
X_train6 = pd.read_csv('temp_data/X_train_ratio.csv').drop('new_id',axis=1)
X_train6.fillna(0.0)
#X_train9 = pd.read_csv('temp_data/X_train_act_comb_1.csv').drop('new_id',axis=1)
#X_train10 = pd.read_csv('temp_data/train_playpattern_mean_encoding.csv').drop('new_id',axis=1)
#X_train11 = pd.read_csv('temp_data/train_interaction_sum_30.csv').drop('new_id',axis=1)

## test
X_test1 = pd.read_csv('temp_data/X_test_stat.csv')
X_test2 = pd.read_csv('temp_data/X_test_easy_time.csv').drop('new_id',axis=1)
X_test2.columns = X_train2.columns
X_test3 = pd.read_csv('temp_data/X_test_게임활동_time.csv').drop('new_id',axis=1)
X_test3.columns = X_train3.columns
X_test6 = pd.read_csv('temp_data/X_test_ratio.csv').drop('new_id',axis=1)
X_test6.fillna(0.0)
#X_test9 = pd.read_csv('temp_data/X_test_act_comb_1.csv').drop('new_id',axis=1)
#X_test10 = pd.read_csv('temp_data/test_playpattern_mean_encoding.csv').drop('new_id',axis=1)
#X_test11 = pd.read_csv('temp_data/test_interaction_sum_30.csv').drop('new_id',axis=1)

## guild and trade and party
X_train4 = pd.read_csv('temp_data/temp_guild_train.csv').drop('new_id',axis=1)
X_train5 = pd.read_csv('temp_data/temp_trade_train.csv').drop('new_id',axis=1)
X_test4 = pd.read_csv('temp_data/temp_guild_test.csv').drop('new_id',axis=1)
X_test5 = pd.read_csv('temp_data/temp_trade_test.csv').drop('new_id',axis=1)
X_train7 = pd.read_csv('temp_data/X_train_party.csv').drop('new_id',axis=1)
X_test7 = pd.read_csv('temp_data/X_test_party.csv').drop('new_id',axis=1)
X_train8 = pd.read_csv('temp_data/training_trade.csv').drop('new_id',axis=1)
X_test8 = pd.read_csv('temp_data/test_trade.csv').drop('new_id',axis=1)
