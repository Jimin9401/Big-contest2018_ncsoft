# %% [markdown]
# ### Import module and Load data

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
from IPython.display import clear_output

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from scipy.stats import kstest

from sklearn.metrics import precision_score, recall_score
from sklearn.model_selection import StratifiedKFold

# %%
def f1(X_val, y_val, model,mapping):
    """
    Model evaluation function for multiclass classification problem
    1) F-1 score, Precision, Recall
    2) ROC curve, PR curve는 추후에 생각
    """
 
    #### predict the value
    y_pred = model.predict(X_val)

    #print('-'*50)
    #print('2. F1-score')
    
    # inverse pre/ rec
    pre = precision_score(y_true = y_val, y_pred = y_pred, average=None)
    rec = recall_score(y_true = y_val, y_pred = y_pred, average=None)

    # f1 measure
    f1_score = 8/(sum(1/pre) + sum(1/rec))
    
    # view - precision recall
    table = pd.DataFrame([])

    for i,k in enumerate(mapping.keys()):
        table[k] = [pre[i],rec[i]]
    table.index = ['precision','recall']
    # print(table)
    
    # view - f1
    #print('F1_score %.3f'%f1_score)
    #print('='*50)
    return f1_score

# %%
#### load data set
## train
X_train1 = pd.read_csv('X_train_stat.csv')
X_train1.columns = ['new_id'] + [x +'_stat' for x in X_train1.columns[1:]]
X_train2 = pd.read_csv('X_train_easy_time.csv').drop('new_id',axis=1)
X_train2.columns = [x +'_basic_time' for x in X_train2.columns]
X_train3 = pd.read_csv('X_train_게임활동_time.csv').drop('new_id',axis=1)
X_train3.columns = [x +'_time_series' for x in X_train3.columns]


## test
X_test1 = pd.read_csv('X_test_stat.csv')
X_test1.columns = X_train1.columns
X_test2 = pd.read_csv('X_test_easy_time.csv').drop('new_id',axis=1)
X_test2.columns = X_train2.columns
X_test3 = pd.read_csv('X_test_게임활동_time.csv').drop('new_id',axis=1)
X_test3.columns = X_train3.columns


## guild and trade
X_train4 = pd.read_csv('../MODELS/temp_data/temp_guild_train.csv').drop('new_id',axis=1)
X_train5 = pd.read_csv('../MODELS/temp_data/temp_trade_train.csv').drop('new_id',axis=1)
X_test4 = pd.read_csv('../MODELS/temp_data/temp_guild_test.csv').drop('new_id',axis=1)
X_test5 = pd.read_csv('../MODELS/temp_data/temp_trade_test.csv').drop('new_id',axis=1)

# %%
X_train = pd.concat((X_train1,X_train2,X_train3,X_train4,X_train5),axis=1).drop('new_id',axis=1)
X_test = pd.concat((X_test1,X_test2,X_test3,X_test4,X_test5),axis=1).drop('new_id',axis=1)

# %%
#### load class
train_label = pd.read_csv('../lite_data/train_label_lite.csv')
#hasher = pd.read_csv('temp_data/test_id.csv')
label_map = {'retained':0,'2month':1,'month':2,'week':3}
inv_map = {label_map[k]:k for k in label_map.keys()}
y_train = pd.Series([label_map[l] for l in train_label.label]).values

# %% [markdown]
# ---

# %% [markdown]
# ### Preprocessing

# %%
X_train.columns.tolist()
# Out:
# ['payment_amount_CAT_stat',
#  'payment_amount_min_stat',
#  'payment_amount_max_stat',
#  'payment_amount_range_stat',
#  'payment_amount_median_stat',
#  'payment_amount_sum_stat',
#  'cnt_dt_CAT_stat',
#  'cnt_dt_min_stat',
#  'cnt_dt_max_stat',
#  'cnt_dt_range_stat',
#  'cnt_dt_median_stat',
#  'cnt_dt_sum_stat',
#  'play_time_CAT_stat',
#  'play_time_min_stat',
#  'play_time_max_stat',
#  'play_time_range_stat',
#  'play_time_median_stat',
#  'play_time_sum_stat',
#  'game_combat_time_CAT_stat',
#  'game_combat_time_min_stat',
#  'game_combat_time_max_stat',
#  'game_combat_time_range_stat',
#  'game_combat_time_median_stat',
#  'game_combat_time_sum_stat',
#  'get_money_CAT_stat',
#  'get_money_min_stat',
#  'get_money_max_stat',
#  'get_money_range_stat',
#  'get_money_median_stat',
#  'get_money_sum_stat',
#  'cnt_use_buffitem_CAT_stat',
#  'cnt_use_buffitem_min_stat',
#  'cnt_use_buffitem_max_stat',
#  'cnt_use_buffitem_range_stat',
#  'cnt_use_buffitem_median_stat',
#  'cnt_use_buffitem_sum_stat',
#  'npc_exp_CAT_stat',
#  'npc_exp_min_stat',
#  'npc_exp_max_stat',
#  'npc_exp_range_stat',
#  'npc_exp_median_stat',
#  'npc_exp_sum_stat',
#  'npc_hongmun_CAT_stat',
#  'npc_hongmun_min_stat',
#  'npc_hongmun_max_stat',
#  'npc_hongmun_range_stat',
#  'npc_hongmun_median_stat',
#  'npc_hongmun_sum_stat',
#  'quest_exp_CAT_stat',
#  'quest_exp_min_stat',
#  'quest_exp_max_stat',
#  'quest_exp_range_stat',
#  'quest_exp_median_stat',
#  'quest_exp_sum_stat',
#  'quest_hongmun_CAT_stat',
#  'quest_hongmun_min_stat',
#  'quest_hongmun_max_stat',
#  'quest_hongmun_range_stat',
#  'quest_hongmun_median_stat',
#  'quest_hongmun_sum_stat',
#  'item_hongmun_CAT_stat',
#  'item_hongmun_min_stat',
#  'item_hongmun_max_stat',
#  'item_hongmun_range_stat',
#  'item_hongmun_median_stat',
#  'item_hongmun_sum_stat',
#  'duel_cnt_CAT_stat',
#  'duel_cnt_min_stat',
#  'duel_cnt_max_stat',
#  'duel_cnt_range_stat',
#  'duel_cnt_median_stat',
#  'duel_cnt_sum_stat',
#  'partybattle_cnt_CAT_stat',
#  'partybattle_cnt_min_stat',
#  'partybattle_cnt_max_stat',
#  'partybattle_cnt_range_stat',
#  'partybattle_cnt_median_stat',
#  'partybattle_cnt_sum_stat',
#  'cnt_enter_inzone_solo_CAT_stat',
#  'cnt_enter_inzone_solo_min_stat',
#  'cnt_enter_inzone_solo_max_stat',
#  'cnt_enter_inzone_solo_range_stat',
#  'cnt_enter_inzone_solo_median_stat',
#  'cnt_enter_inzone_solo_sum_stat',
#  'cnt_enter_inzone_light_CAT_stat',
#  'cnt_enter_inzone_light_min_stat',
#  'cnt_enter_inzone_light_max_stat',
#  'cnt_enter_inzone_light_range_stat',
#  'cnt_enter_inzone_light_median_stat',
#  'cnt_enter_inzone_light_sum_stat',
#  'cnt_enter_inzone_skilled_CAT_stat',
#  'cnt_enter_inzone_skilled_min_stat',
#  'cnt_enter_inzone_skilled_max_stat',
#  'cnt_enter_inzone_skilled_range_stat',
#  'cnt_enter_inzone_skilled_median_stat',
#  'cnt_enter_inzone_skilled_sum_stat',
#  'cnt_enter_inzone_normal_CAT_stat',
#  'cnt_enter_inzone_normal_min_stat',
#  'cnt_enter_inzone_normal_max_stat',
#  'cnt_enter_inzone_normal_range_stat',
#  'cnt_enter_inzone_normal_median_stat',
#  'cnt_enter_inzone_normal_sum_stat',
#  'cnt_enter_raid_CAT_stat',
#  'cnt_enter_raid_min_stat',
#  'cnt_enter_raid_max_stat',
#  'cnt_enter_raid_range_stat',
#  'cnt_enter_raid_median_stat',
#  'cnt_enter_raid_sum_stat',
#  'cnt_enter_raid_light_CAT_stat',
#  'cnt_enter_raid_light_min_stat',
#  'cnt_enter_raid_light_max_stat',
#  'cnt_enter_raid_light_range_stat',
#  'cnt_enter_raid_light_median_stat',
#  'cnt_enter_raid_light_sum_stat',
#  'normal_chat_CAT_stat',
#  'normal_chat_min_stat',
#  'normal_chat_max_stat',
#  'normal_chat_range_stat',
#  'normal_chat_median_stat',
#  'normal_chat_sum_stat',
#  'whisper_chat_CAT_stat',
#  'whisper_chat_min_stat',
#  'whisper_chat_max_stat',
#  'whisper_chat_range_stat',
#  'whisper_chat_median_stat',
#  'whisper_chat_sum_stat',
#  'district_chat_CAT_stat',
#  'district_chat_min_stat',
#  'district_chat_max_stat',
#  'district_chat_range_stat',
#  'district_chat_median_stat',
#  'district_chat_sum_stat',
#  'party_chat_CAT_stat',
#  'party_chat_min_stat',
#  'party_chat_max_stat',
#  'party_chat_range_stat',
#  'party_chat_median_stat',
#  'party_chat_sum_stat',
#  'guild_chat_CAT_stat',
#  'guild_chat_min_stat',
#  'guild_chat_max_stat',
#  'guild_chat_range_stat',
#  'guild_chat_median_stat',
#  'guild_chat_sum_stat',
#  'making_cnt_CAT_stat',
#  'making_cnt_min_stat',
#  'making_cnt_max_stat',
#  'making_cnt_range_stat',
#  'making_cnt_median_stat',
#  'making_cnt_sum_stat',
#  'cnt_enter_bam_CAT_stat',
#  'faction_chat_CAT_stat',
#  'gathering_cnt_CAT_stat',
#  'payment_amount_median_basic_time',
#  'payment_amount_mean_basic_time',
#  'payment_amount_var_basic_time',
#  'payment_amount_skew_basic_time',
#  'payment_amount_kurt_basic_time',
#  'payment_amount_MA_1_basic_time',
#  'payment_amount_MA_2_basic_time',
#  'payment_amount_MA_3_basic_time',
#  'payment_amount_MA_4_basic_time',
#  'payment_amount_MA_5_basic_time',
#  'payment_amount_cycle_basic_time',
#  'party_chat_median_basic_time',
#  'party_chat_mean_basic_time',
#  'party_chat_var_basic_time',
#  'party_chat_skew_basic_time',
#  'party_chat_kurt_basic_time',
#  'party_chat_MA_1_basic_time',
#  'party_chat_MA_2_basic_time',
#  'party_chat_MA_3_basic_time',
#  'party_chat_MA_4_basic_time',
#  'party_chat_MA_5_basic_time',
#  'party_chat_cycle_basic_time',
#  'whisper_chat_median_basic_time',
#  'whisper_chat_mean_basic_time',
#  'whisper_chat_var_basic_time',
#  'whisper_chat_skew_basic_time',
#  'whisper_chat_kurt_basic_time',
#  'whisper_chat_MA_1_basic_time',
#  'whisper_chat_MA_2_basic_time',
#  'whisper_chat_MA_3_basic_time',
#  'whisper_chat_MA_4_basic_time',
#  'whisper_chat_MA_5_basic_time',
#  'whisper_chat_cycle_basic_time',
#  'normal_chat_median_basic_time',
#  'normal_chat_mean_basic_time',
#  'normal_chat_var_basic_time',
#  'normal_chat_skew_basic_time',
#  'normal_chat_kurt_basic_time',
#  'normal_chat_MA_1_basic_time',
#  'normal_chat_MA_2_basic_time',
#  'normal_chat_MA_3_basic_time',
#  'normal_chat_MA_4_basic_time',
#  'normal_chat_MA_5_basic_time',
#  'normal_chat_cycle_basic_time',
#  'guild_chat_median_basic_time',
#  'guild_chat_mean_basic_time',
#  'guild_chat_var_basic_time',
#  'guild_chat_skew_basic_time',
#  'guild_chat_kurt_basic_time',
#  'guild_chat_MA_1_basic_time',
#  'guild_chat_MA_2_basic_time',
#  'guild_chat_MA_3_basic_time',
#  'guild_chat_MA_4_basic_time',
#  'guild_chat_MA_5_basic_time',
#  'guild_chat_cycle_basic_time',
#  'quest_hongmun_median_basic_time',
#  'quest_hongmun_mean_basic_time',
#  'quest_hongmun_var_basic_time',
#  'quest_hongmun_skew_basic_time',
#  'quest_hongmun_kurt_basic_time',
#  'quest_hongmun_MA_1_basic_time',
#  'quest_hongmun_MA_2_basic_time',
#  'quest_hongmun_MA_3_basic_time',
#  'quest_hongmun_MA_4_basic_time',
#  'quest_hongmun_MA_5_basic_time',
#  'quest_hongmun_cycle_basic_time',
#  'npc_hongmun_median_basic_time',
#  'npc_hongmun_mean_basic_time',
#  'npc_hongmun_var_basic_time',
#  'npc_hongmun_skew_basic_time',
#  'npc_hongmun_kurt_basic_time',
#  'npc_hongmun_MA_1_basic_time',
#  'npc_hongmun_MA_2_basic_time',
#  'npc_hongmun_MA_3_basic_time',
#  'npc_hongmun_MA_4_basic_time',
#  'npc_hongmun_MA_5_basic_time',
#  'npc_hongmun_cycle_basic_time',
#  'item_hongmun_median_basic_time',
#  'item_hongmun_mean_basic_time',
#  'item_hongmun_var_basic_time',
#  'item_hongmun_skew_basic_time',
#  'item_hongmun_kurt_basic_time',
#  'item_hongmun_MA_1_basic_time',
#  'item_hongmun_MA_2_basic_time',
#  'item_hongmun_MA_3_basic_time',
#  'item_hongmun_MA_4_basic_time',
#  'item_hongmun_MA_5_basic_time',
#  'item_hongmun_cycle_basic_time',
#  'inzone_light_median_basic_time',
#  'inzone_light_mean_basic_time',
#  'inzone_light_var_basic_time',
#  'inzone_light_skew_basic_time',
#  'inzone_light_kurt_basic_time',
#  'inzone_light_MA_1_basic_time',
#  'inzone_light_MA_2_basic_time',
#  'inzone_light_MA_3_basic_time',
#  'inzone_light_MA_4_basic_time',
#  'inzone_light_MA_5_basic_time',
#  'inzone_light_cycle_basic_time',
#  'inzone_normal_median_basic_time',
#  'inzone_normal_mean_basic_time',
#  'inzone_normal_var_basic_time',
#  'inzone_normal_skew_basic_time',
#  'inzone_normal_kurt_basic_time',
#  'inzone_normal_MA_1_basic_time',
#  'inzone_normal_MA_2_basic_time',
#  'inzone_normal_MA_3_basic_time',
#  'inzone_normal_MA_4_basic_time',
#  'inzone_normal_MA_5_basic_time',
#  'inzone_normal_cycle_basic_time',
#  'cnt_dt_median_time_series',
#  'cnt_dt_mean_time_series',
#  'cnt_dt_var_time_series',
#  'cnt_dt_skew_time_series',
#  'cnt_dt_kurt_time_series',
#  'cnt_dt_MA_1_time_series',
#  'cnt_dt_MA_2_time_series',
#  'cnt_dt_MA_3_time_series',
#  'cnt_dt_MA_4_time_series',
#  'cnt_dt_MA_5_time_series',
#  'cnt_dt_diff1_time_series',
#  'cnt_dt_diff2_time_series',
#  'cnt_dt_diff3_time_series',
#  'cnt_dt_diff4_time_series',
#  'cnt_dt_diff5_time_series',
#  'cnt_dt_diff6_time_series',
#  'cnt_dt_diff7_time_series',
#  'cnt_dt_diff_w2_by_last_time_series',
#  'cnt_dt_diff_w4_by_last_time_series',
#  'cnt_dt_diff_w8_by_last_time_series',
#  'cnt_dt_cycle_time_series',
#  'play_time_median_time_series',
#  'play_time_mean_time_series',
#  'play_time_var_time_series',
#  'play_time_skew_time_series',
#  'play_time_kurt_time_series',
#  'play_time_MA_1_time_series',
#  'play_time_MA_2_time_series',
#  'play_time_MA_3_time_series',
#  'play_time_MA_4_time_series',
#  'play_time_MA_5_time_series',
#  'play_time_diff1_time_series',
#  'play_time_diff2_time_series',
#  'play_time_diff3_time_series',
#  'play_time_diff4_time_series',
#  'play_time_diff5_time_series',
#  'play_time_diff6_time_series',
#  'play_time_diff7_time_series',
#  'play_time_diff_w2_by_last_time_series',
#  'play_time_diff_w4_by_last_time_series',
#  'play_time_diff_w8_by_last_time_series',
#  'play_time_cycle_time_series',
#  'game_combat_time_median_time_series',
#  'game_combat_time_mean_time_series',
#  'game_combat_time_var_time_series',
#  'game_combat_time_skew_time_series',
#  'game_combat_time_kurt_time_series',
#  'game_combat_time_MA_1_time_series',
#  'game_combat_time_MA_2_time_series',
#  'game_combat_time_MA_3_time_series',
#  'game_combat_time_MA_4_time_series',
#  'game_combat_time_MA_5_time_series',
#  'game_combat_time_diff1_time_series',
#  'game_combat_time_diff2_time_series',
#  'game_combat_time_diff3_time_series',
#  'game_combat_time_diff4_time_series',
#  'game_combat_time_diff5_time_series',
#  'game_combat_time_diff6_time_series',
#  'game_combat_time_diff7_time_series',
#  'game_combat_time_diff_w2_by_last_time_series',
#  'game_combat_time_diff_w4_by_last_time_series',
#  'game_combat_time_diff_w8_by_last_time_series',
#  'game_combat_time_cycle_time_series',
#  'get_money_median_time_series',
#  'get_money_mean_time_series',
#  'get_money_var_time_series',
#  'get_money_skew_time_series',
#  'get_money_kurt_time_series',
#  'get_money_MA_1_time_series',
#  'get_money_MA_2_time_series',
#  'get_money_MA_3_time_series',
#  'get_money_MA_4_time_series',
#  'get_money_MA_5_time_series',
#  'get_money_diff1_time_series',
#  'get_money_diff2_time_series',
#  'get_money_diff3_time_series',
#  'get_money_diff4_time_series',
#  'get_money_diff5_time_series',
#  'get_money_diff6_time_series',
#  'get_money_diff7_time_series',
#  'get_money_diff_w2_by_last_time_series',
#  'get_money_diff_w4_by_last_time_series',
#  'get_money_diff_w8_by_last_time_series',
#  'get_money_cycle_time_series',
#  'cnt_use_buffitem_median_time_series',
#  'cnt_use_buffitem_mean_time_series',
#  'cnt_use_buffitem_var_time_series',
#  'cnt_use_buffitem_skew_time_series',
#  'cnt_use_buffitem_kurt_time_series',
#  'cnt_use_buffitem_MA_1_time_series',
#  'cnt_use_buffitem_MA_2_time_series',
#  'cnt_use_buffitem_MA_3_time_series',
#  'cnt_use_buffitem_MA_4_time_series',
#  'cnt_use_buffitem_MA_5_time_series',
#  'cnt_use_buffitem_diff1_time_series',
#  'cnt_use_buffitem_diff2_time_series',
#  'cnt_use_buffitem_diff3_time_series',
#  'cnt_use_buffitem_diff4_time_series',
#  'cnt_use_buffitem_diff5_time_series',
#  'cnt_use_buffitem_diff6_time_series',
#  'cnt_use_buffitem_diff7_time_series',
#  'cnt_use_buffitem_diff_w2_by_last_time_series',
#  'cnt_use_buffitem_diff_w4_by_last_time_series',
#  'cnt_use_buffitem_diff_w8_by_last_time_series',
#  'cnt_use_buffitem_cycle_time_series',
#  'num_guild',
#  'guild_size',
#  'net_lcc',
#  'net_DegCen',
#  'net_ClsCen',
#  'net_BetCen',
#  'net_EigCen',
#  'trade_InDegCen',
#  'trade_outDegCen',
#  'trade_InDeg',
#  'trade_OutDeg']

# %%
#### columns dict 
numeric_col = {i:c for i,c in enumerate(X_train.columns.tolist()) if 'CAT' not in c}
categoric_col = {i:c for i,c in enumerate(X_train.columns.tolist()) if 'CAT' in c}

# %%
total_col = dict()
total_col.update(numeric_col)
total_col.update(categoric_col)

# %%
#### 최솟값 0패딩
X_train = X_train.fillna(0.0)
X_test = X_test.fillna(0.0)

# %%
#### scaling 
class Scaler(object):
    def __init__(self):
        self.sc = StandardScaler()
        self.mn = MinMaxScaler()
        
    def fit_transform(self, X_train, X_test):
        self.cols = X_train.columns.tolist()
        
        for c in self.cols:
            _, n = kstest(X_train[c],'norm')
            if n < 0.1:
                pass
            else:
                if X_train[c].min() < 0:
                    X_train[c] = self.sc.fit_transform(X_train[c])
                    X_test[c] = self.sc.transform(X_test[c])
                    
                else:
                    temp_tr = X_train[c].copy()
                    temp_te = X_train[c].copy()
                    X_train[c] = np.log1p(X_train[c])
                    X_test[c] = np.log1p(X_test[c])
                    
                    _, m = kstest(X_train[c],'norm')
                    
                    if m < 0.1:
                        pass
                    else:
                        
                        
                        X_train[c] = np.sqrt(temp_tr)
                        X_test[c] = np.sqrt(temp_te)
                        
        
        X_train = self.mn.fit_transform(X_train)
        X_test = self.mn.transform(X_test)
        
        return X_train, X_test

# %%
#### scaler
scaler= Scaler()
X_train, X_test= scaler.fit_transform(X_train,X_test)

# %% [markdown]
# ---

# %% [markdown]
# ### Converting Data into Tensors

# %%
Nums = [tf.feature_column.numeric_column(c) for c in numeric_col.values()]
Cats = [tf.feature_column.numeric_column(c) for c in categoric_col.values()]
feature_name = Nums + Cats

# %%
# define estimator
optimizer = tf.train.FtrlOptimizer(learning_rate=0.1, l2_regularization_strength=1.0)
estimator = tf.estimator.LinearClassifier(feature_columns = feature_name, n_classes=4, optimizer=optimizer,model_dir='/tmp/svm')

# %%
def input_fn(dataset):
    def _fn():
        features = {feature_name : tf.constant(dataset.data)}
        label =

# %%
## define input_fn_train 
input_fn_train = tf.estimator.inputs.numpy_input_fn(x = {total_col[i]:arr for i, arr in enumerate(X_train[train].T)},
                                                    y = y_train[train], batch_size = 400, num_epochs = 5, shuffle = True)

## define input_fn_test
input_fn_test = tf.estimator.inputs.numpy_input_fn(x = {total_col[i]:arr for i, arr in enumerate(X_train[test].T)},
                                                y = y_train[test], batch_size = 500, num_epochs = None, shuffle = True)

# %%
## optimizer
optimizer = tf.train.FtrlOptimizer(learning_rate=0.1, l2_regularization_strength=1.0)
estimator = tf.estimator.LinearClassifier(feature_columns = Nums + Cats, n_classes=4, optimizer=optimizer)
estimator.train(input_fn = input_fn_train, steps=1000)
result = estimator.evaluate(input_fn_test)

# %%
#### cross validation
kfold = StratifiedKFold(n_splits = 5 ,random_state = 7,shuffle = True).split(X_train, y_train)
Nums = [tf.feature_column.numeric_column(c) for c in numeric_col.values()]
Cats = [tf.feature_column.numeric_column(c) for c in categoric_col.values()]
for k, (train, test) in enumerate(kfold):
    
    ## define input_fn_train 
    input_fn_train = tf.estimator.inputs.numpy_input_fn(x = {total_col[i]:arr for i, arr in enumerate(X_train[train].T)},
                                                        y = y_train[train], batch_size = 400, num_epochs = 5, shuffle = True)
    
    ## define input_fn_test
    input_fn_test = tf.estimator.inputs.numpy_input_fn(x = {total_col[i]:arr for i, arr in enumerate(X_train[test].T)},
                                                    y = y_train[test], batch_size = 500, num_epochs = None, shuffle = True)
    
    ## optimizer

    estimator.train(input_fn = input_fn_train, steps=1000)
    result = estimator.evaluate(input_fn_test)
    
    clear_output()
    
    print('=========='+str(k)+'==========')
    for key,value in sorted(result.items()):
        print('%s: %s' % (key, value))
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpv3izdesn
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpv3izdesn', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f8f9edb74e0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpv3izdesn/model.ckpt.
# INFO:tensorflow:loss = 554.5177, step = 0
# INFO:tensorflow:global_step/sec: 3.22011
# INFO:tensorflow:loss = 372.5054, step = 100 (31.059 sec)
# INFO:tensorflow:global_step/sec: 3.74091
# INFO:tensorflow:loss = 363.30966, step = 200 (26.737 sec)
# INFO:tensorflow:global_step/sec: 3.93264
# INFO:tensorflow:loss = 375.47858, step = 300 (25.426 sec)
# INFO:tensorflow:global_step/sec: 3.96167
# INFO:tensorflow:loss = 343.2652, step = 400 (25.244 sec)
# INFO:tensorflow:global_step/sec: 3.97454
# INFO:tensorflow:loss = 352.5543, step = 500 (25.155 sec)
# INFO:tensorflow:global_step/sec: 3.99953
# INFO:tensorflow:loss = 341.88736, step = 600 (25.002 sec)
# INFO:tensorflow:global_step/sec: 3.99587
# INFO:tensorflow:loss = 354.18716, step = 700 (25.026 sec)
# INFO:tensorflow:global_step/sec: 3.97907
# INFO:tensorflow:loss = 353.54065, step = 800 (25.132 sec)
# INFO:tensorflow:global_step/sec: 3.98377
# INFO:tensorflow:loss = 337.27844, step = 900 (25.101 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpv3izdesn/model.ckpt.
# INFO:tensorflow:Loss for final step: 344.43277.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-29-11:29:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpv3izdesn/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-767c55f805cc> in <module>()
#      17     estimator = tf.estimator.LinearClassifier(feature_columns = Nums + Cats, n_classes=4, optimizer=optimizer)
#      18     estimator.train(input_fn_train)
# ---> 19     result = estimator.evaluate(input_fn_test)
#      20
#      21     clear_output()
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in evaluate(self, input_fn, steps, hooks, checkpoint_path, name)
#     415         hooks=hooks,
#     416         checkpoint_path=checkpoint_path,
# --> 417         name=name)
#     418
#     419   def _convert_eval_steps_to_hooks(self, steps):
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _evaluate_model(self, input_fn, hooks, checkpoint_path, name)
#     959           final_ops=eval_dict,
#     960           hooks=all_hooks,
# --> 961           config=self._session_config)
#     962
#     963       _write_dict_to_summary(
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/training/evaluation.py in _evaluate_once(checkpoint_path, master, scaffold, eval_ops, feed_dict, final_ops, final_ops_feed_dict, hooks, config)
#     210     if eval_ops is not None:
#     211       while not session.should_stop():
# --> 212         session.run(eval_ops, feed_dict)
#     213
#     214   logging.info('Finished evaluation at ' + time.strftime('%Y-%m-%d-%H:%M:%S',
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     544                           feed_dict=feed_dict,
#     545                           options=options,
# --> 546                           run_metadata=run_metadata)
#     547
#     548   def run_step_fn(self, step_fn):
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1020                               feed_dict=feed_dict,
#    1021                               options=options,
# -> 1022                               run_metadata=run_metadata)
#    1023       except _PREEMPTION_ERRORS as e:
#    1024         logging.info('An error was raised. This may be due to a preemption in '
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1096   def run(self, *args, **kwargs):
#    1097     try:
# -> 1098       return self._sess.run(*args, **kwargs)
#    1099     except _PREEMPTION_ERRORS:
#    1100       raise
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1168                                   feed_dict=feed_dict,
#    1169                                   options=options,
# -> 1170                                   run_metadata=run_metadata)
#    1171
#    1172     for hook in self._hooks:
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#     948
#     949   def run(self, *args, **kwargs):
# --> 950     return self._sess.run(*args, **kwargs)
#     951
#     952   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
