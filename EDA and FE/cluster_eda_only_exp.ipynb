# %%
# 패키지
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from  itertools import combinations
from sklearn import linear_model
sns.set(palette='pastel')
sns.set(font_scale=2)

# %%
labels=pd.read_csv('FE and error_set/error_set_0.741.csv')

# %%
train_data=pd.read_csv('X_train_final.csv')
test_data=pd.read_csv('X_test_final.csv')

# %%
train_data_c=train_data.copy()
test_data_c=test_data.copy()

# %%
train_act=pd.read_csv('transformed/train_real_values.csv')
test_act=pd.read_csv('transformed/test_real_datas_int.csv')

# %%
train_act_c=train_act.copy()
test_act_c=test_act.copy()

# %%
# train

# %%
train_group_user=pd.read_csv('train_group_user_df.csv')
train_group_act=pd.read_csv('train_group_act_df.csv')
test_group_user=pd.read_csv('test_group_user_df.csv')
test_group_act=pd.read_csv('test_group_act_df.csv')

# %%
labels[train_group_user.group_b]
# Out:
#         new_id     label    y_pred
# 1          tr1      week      week
# 8          tr8    2month    2month
# 9          tr9    2month    2month
# 10        tr10     month     month
# 13        tr13    2month    2month
# 17        tr17     month     month
# 26        tr26    2month    2month
# 28        tr28     month    2month
# 29        tr29     month    2month
# 32        tr32    2month      week
# 35        tr35      week      week
# 44        tr44     month     month
# 52        tr52     month      week
# 59        tr59     month    2month
# 66        tr66  retained    2month
# 67        tr67     month    2month
# 70        tr70     month     month
# 74        tr74     month    2month
# 76        tr76      week      week
# 78        tr78     month    2month
# 88        tr88     month    2month
# 93        tr93     month     month
# 97        tr97    2month     month
# 107      tr107    2month     month
# 108      tr108    2month    2month
# 117      tr117    2month    2month
# ...

# %%
train_act[train_group_act.group_b]
# Out:
#         cnt_dt      play_time       npc_exp  npc_hongmun     quest_exp  \
# 1          1.0   39907.000039  46489.000007          0.0  9.714700e+05
# 32         2.0    1133.000001     28.000000          0.0  8.610000e+03
# 33         4.0    1548.000002     28.000000          0.0  8.610000e+03
# 34         5.0     595.000001      0.000000          0.0  0.000000e+00
# 35         4.0     501.000000      0.000000          0.0  0.000000e+00
# 36         5.0     540.000001      0.000000          0.0  0.000000e+00
# 37         1.0    1136.000001     28.000000          0.0  8.610000e+03
# 38         2.0     120.000000      0.000000          0.0  0.000000e+00
# 53         3.0     352.000000      0.000000          0.0  0.000000e+00
# 54         2.0     236.000000      0.000000          0.0  0.000000e+00
# 55         5.0     511.000000      0.000000          0.0  0.000000e+00
# 56         1.0     120.000000      0.000000          0.0  0.000000e+00
# ...

# %%
(train_data.get_money_Count!=0)
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
# 5        False
# 6         True
# 7        False
# 8        False
# 9        False
# 10       False
# 11        True
# 12       False
# 13       False
# 14       False
# 15       False
# 16        True
# 17       False
# 18       False
# 19        True
# 20       False
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26       False
# 27        True
# 28       False
# 29       False
#          ...
# 99970     True
# 99971     True
# 99972     True
# 99973     True
# 99974    False
# 99975    False
# 99976     True
# 99977    False
# 99978     True
# 99979    False
# 99980     True
# 99981     True
# 99982    False
# 99983     True
# 99984    False
# 99985    False
# 99986     True
# 99987     True
# 99988     True
# 99989    False
# 99990    False
# 99991     True
# 99992     True
# 99993     True
# 99994     True
# 99995    False
# 99996    False
# ...

# %%
sum(labels[(train_data.get_money_Count.astype(int)!=0)&(train_group_user.group_b)].label!=labels[(train_data.get_money_Count.astype(int)!=0)&(train_group_user.group_b)].y_pred)
# Out:
# 966

# %%
labels[(train_data.get_money_Count.astype(int)==0)&(train_group_user.group_b)].label.value_counts()
# Out:
# 2month      8922
# month       6317
# retained    1831
# week         222
# Name: label, dtype: int64

# %%
train_data[(train_data.get_money_Count.astype(int)==0)&(train_group_user.group_b)].first_week.value_counts()
# Out:
# 8    8150
# 6    3014
# 7    2600
# 3    1602
# 5     827
# 4     820
# 1     247
# 2      32
# Name: first_week, dtype: int64

# %%
train_data.columns.tolist()
# Out:
# ['play_time_Count',
#  'cnt_enter_inzone_skilled_Count',
#  'making_cnt_Count',
#  'normal_chat_median_basic_time',
#  'first_week_cnt_clear_raid_light',
#  'cnt_enter_raid_light_range_stat',
#  'payment_amount_MA_5_basic_time',
#  'duel_cnt_sum_stat',
#  'trade_InDeg',
#  'partybattle_cnt_sum_stat',
#  'payment_amount_median_basic_time',
#  'partybattle_cnt_max_stat',
#  'payment_amount_kurt_basic_time',
#  'cnt_enter_raid_light_median_stat',
#  'guild_chat_MA_1_basic_time',
#  'whisper_chat_Count',
#  'cnt_enter_inzone_light_Count',
#  'payment_amount_MA_1_basic_time',
#  'cnt_enter_raid_light_max_stat',
#  'payment_amount_by_play_time',
#  'normal_chat_MA_2_basic_time',
#  'cnt_dt_Count',
#  'normal_chat_MA_1_basic_time',
#  'payment_amount_MA_3_basic_time',
#  'cnt_enter_raid_light_Count',
#  'district_chat_max_stat',
#  'payment_amount_min_stat',
#  'first_week_making_cnt',
#  'payment_amount_MA_4_basic_time',
#  'cnt_use_buffitem_Count',
#  'game_combat_time_Count',
# ...

# %%
for i in train_data.columns:
    print(i,'\n',train_data[(train_data.get_money_Count.astype(int)==0)&(train_group_user.group_b)][i].value_counts(),'\n')
# Out:
# play_time_Count
#  1    8151
# 2    3902
# 3    2492
# 5    1365
# 4     940
# 6     233
# 8     198
# 7      11
# Name: play_time_Count, dtype: int64
#
# cnt_enter_inzone_skilled_Count
#  0    17292
# Name: cnt_enter_inzone_skilled_Count, dtype: int64
#
# making_cnt_Count
#  0    17281
# 1        4
# 5        2
# 3        2
# 2        2
# 4        1
# Name: making_cnt_Count, dtype: int64
#
# normal_chat_median_basic_time
#  0.0    17291
# 1.0        1
# Name: normal_chat_median_basic_time, dtype: int64
#
# first_week_cnt_clear_raid_light
#  0.0    17292
# Name: first_week_cnt_clear_raid_light, dtype: int64
#
# cnt_enter_raid_light_range_stat
#  Series([], Name: cnt_enter_raid_light_range_stat, dtype: int64)
#
# payment_amount_MA_5_basic_time
#  0.0         17273
# 4950.0          8
# 74992.5         2
# 5197.5          2
# 126225.0        1
# 12622.5         1
# 124492.5        1
# 33412.5         1
# 123750.0        1
# 10395.0         1
# 7425.0          1
# ...
